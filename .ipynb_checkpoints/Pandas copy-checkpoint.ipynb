# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Series

# %%
sales = [1402, 548, 1122]

# %%
sales_arr = np.array(sales)

# %%
sales_arr
# Out:
# array([1402,  548, 1122])

# %%
# TOM INCOME
sales_arr[1]
# Out:
# 548

# %%
sales_series = pd.Series(sales_arr)

# %%
sales_series
# Out:
# 0    1402
# 1     548
# 2    1122
# dtype: int64

# %%
# TOM INCOME
sales_series[1]
# Out:
# 548

# %%
names = ["Ellie", "Tom", "Mike"]

# %%
sales_series = pd.Series(sales_arr, names)

# %%
sales_series
# Out:
# Ellie    1402
# Tom       548
# Mike     1122
# dtype: int64

# %%
sales_series["Tom"]
# Out:
# 548

# %%
sales = {"Ellie": 1402, "Tom": 548, "Mike": 1122}

# %%
pd.Series(sales)
# Out:
# Ellie    1402
# Tom       548
# Mike     1122
# dtype: int64

# %% [markdown]
# ## Series Operations

# %%
sales_series["Tom"]
# Out:
# 548

# %%
sales_series * 0.7
# Out:
# Ellie    981.4
# Tom      383.6
# Mike     785.4
# dtype: float64

# %%
april_sales = {"Ellie": 1402, "Tom": 548, "Mike": 1122}

# %%
may_sales = {"Ellie": 704, "Tom": 443, "Ted": 255}

# %%
april_Sales = pd.Series(april_sales)

# %%
may_Sales = pd.Series(may_sales)

# %%
april_Sales
# Out:
# Ellie    1402
# Tom       548
# Mike     1122
# dtype: int64

# %%
may_Sales
# Out:
# Ellie    704
# Tom      443
# Ted      255
# dtype: int64

# %%
april_Sales + may_Sales
# Out:
# Ellie    2106.0
# Mike        NaN
# Ted         NaN
# Tom       991.0
# dtype: float64

# %%
april_Sales.add(may_Sales, fill_value=0)
# Out:
# Ellie    2106.0
# Mike     1122.0
# Ted       255.0
# Tom       991.0
# dtype: float64

# %% [markdown]
# ## Dataframes

# %%
sales = np.random.randint(200,2001, (4,3))

# %%
sales
# Out:
# array([[ 513,  383,  897],
#        [1003, 1994, 1826],
#        [1676,  769, 1669],
#        [ 538, 1112, 1175]])

# %%
names = ["Ellie", "Mike", "Ted", "Tom"]

# %%
months = ["April", "May", "June"]

# %%
df = pd.DataFrame(sales, index=names, columns=months)

# %%
df
# Out:
#        April   May  June
# Ellie    513   383   897
# Mike    1003  1994  1826
# Ted     1676   769  1669
# Tom      538  1112  1175

# %%
ls
# Out:
# NumPy/        Pandas.ipynb

# %%
ls
# Out:
# NumPy/        Pandas.ipynb  data.csv

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                       car       type  year   price finance    day    dealer  \
# 0   Mercedes-Benz A-Class      sedan  2019   39000      no    Sun      Mike
# 1                 Audi A6      sedan  2021   67800     yes    Mon       Sam
# 2           Nissan Altima      sedan  2015   17500      no    Sun      Mike
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000     yes   Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000     yes    Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 7                 Audi A6      sedan  2020   78444      no    Sat  Brittany
# 8           Jeep Wrangler        SUV  2017   33553     yes    Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
df.head()
# Out:
#                      car       type  year  price finance   day  dealer  \
# 0  Mercedes-Benz A-Class      sedan  2019  39000      no   Sun    Mike
# 1                Audi A6      sedan  2021  67800     yes   Mon     Sam
# 2          Nissan Altima      sedan  2015  17500      no   Sun    Mike
# 3      Chevrolet Equinox        SUV  2013   9600      no   Wed  Turner
# 4         Hyundai Accent  hatchback  2017  23000     yes  Thur   Maddy
#
#    customer  social_security sex
# 0   Stanley        555342396   M
# 1  Brittany        887766234  F
# 2      Todd        998573477   M
# 3    Jasime        342234563   F
# 4       Sam        570566354  M

# %%
df["year"]
# Out:
# 0     2019
# 1     2021
# 2     2015
# 3     2013
# 4     2017
# 5     2021
# 6     2000
# 7     2020
# 8     2017
# 9     2012
# 10    2014
# 11    2011
# 12    2015
# 13    2010
# 14    2016
# 15    2021
# 16    2022
# 17    2015
# 18    2019
# 19    2004
# 20    2018
# 21    2020
# 22    2018
# 23    2021
# 24    2021
# 25    2021
# 26    2015
# 27    2014
# 28    2020
# 29    2017
# 30    2000
# 31    2018
# 32    2020
# 33    2021
# 34    2013
# 35    2021
# 36    2021
# 37    2015
# 38    2015
# 39    2017
# 40    2020
# 41    2002
# 42    2020
# 43    2020
# 44    2020
# Name: year, dtype: int64

# %%
type(df["year"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Conditional Selection

# %%
df['year'] > 2015
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4      True
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26    False
# 27    False
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33     True
# 34    False
# 35     True
# 36     True
# 37    False
# 38    False
# 39     True
# 40     True
# 41    False
# 42     True
# 43     True
# 44     True
# Name: year, dtype: bool

# %%
bool_series = df['year'] > 2020

# %%
df[bool_series]
# Out:
#                       car   type  year   price finance   day    dealer  \
# 1                 Audi A6  sedan  2021   67800     yes   Mon       Sam
# 5         Porsche Cayenne  coupe  2021   82000     yes   Fri      Mike
# 15                 BMW M8  coupe  2021  158000     yes   Wed     Maddy
# 16         Toyota 4Runner    SUV  2022   54000      no  Thur      Mike
# 23          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 24                Audi A6  sedan  2021   78444      no  Thur  Brittany
# 25           Genesis GV80    SUV  2021   80444     yes   Mon      Mike
# 33  Mercedes-Benz A-Class  sedan  2021   44032     yes   Mon    Turner
# 35          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 36            Porsche 911  coupe  2021  185543     yes   Mon       Sam
#
#     customer  social_security sex
# 1   Brittany        887766234  F
# 5     Morgan        968258639   F
# 15    Nicole        338559922   F
# 16       Jan        462375343   F
# ...

# %%
df[df['year'] > 2020]
# Out:
#                       car   type  year   price finance   day    dealer  \
# 1                 Audi A6  sedan  2021   67800     yes   Mon       Sam
# 5         Porsche Cayenne  coupe  2021   82000     yes   Fri      Mike
# 15                 BMW M8  coupe  2021  158000     yes   Wed     Maddy
# 16         Toyota 4Runner    SUV  2022   54000      no  Thur      Mike
# 23          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 24                Audi A6  sedan  2021   78444      no  Thur  Brittany
# 25           Genesis GV80    SUV  2021   80444     yes   Mon      Mike
# 33  Mercedes-Benz A-Class  sedan  2021   44032     yes   Mon    Turner
# 35          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 36            Porsche 911  coupe  2021  185543     yes   Mon       Sam
#
#     customer  social_security sex
# 1   Brittany        887766234  F
# 5     Morgan        968258639   F
# 15    Nicole        338559922   F
# 16       Jan        462375343   F
# ...

# %%
df[(df['year'] >= 2020) & (df['price'] >= 100000)]
# Out:
#                  car   type  year   price finance  day dealer   customer  \
# 15            BMW M8  coupe  2021  158000     yes  Wed  Maddy     Nicole
# 21            BMW M8  coupe  2020  140553      no  Wed  Maddy        Sal
# 28  Maserati Levante    SUV  2020  104325     yes  Mon   Mike        Cam
# 32  Maserati Levante    SUV  2020  134325     yes  Sun   Mike       Todd
# 36       Porsche 911  coupe  2021  185543     yes  Mon    Sam        Cam
# 44  Bentley Bentayga    SUV  2020  232000      no  Wed   Mike  Gabrielle
#
#     social_security sex
# 15        338559922   F
# 21        326234886   M
# 28        452685274   M
# 32        952685274   M
# 36        452685274   M
# 44        885353455   F

# %%
df[(df['year'] >= 2020) & (df['sex'] == 'M')]
# Out:
#                       car   type  year   price finance   day    dealer  \
# 21                 BMW M8  coupe  2020  140553      no   Wed     Maddy
# 23          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 24                Audi A6  sedan  2021   78444      no  Thur  Brittany
# 28       Maserati Levante    SUV  2020  104325     yes   Mon      Mike
# 32       Maserati Levante    SUV  2020  134325     yes   Sun      Mike
# 33  Mercedes-Benz A-Class  sedan  2021   44032     yes   Mon    Turner
# 35          Jeep Wrangler    SUV  2021   43553     yes   Fri      Mike
# 36            Porsche 911  coupe  2021  185543     yes   Mon       Sam
# 42           Genesis GV80    SUV  2020   77842     yes   Sat      Mike
#
#    customer  social_security sex
# 21      Sal        326234886   M
# 23      Don        277425852   M
# 24   Qatava        223855366   M
# 28      Cam        452685274   M
# 32     Todd        952685274   M
# 33      Jon        996435345   M
# ...

# %%
df[(df['day'] == 'Sun') | (df['day'] == 'Sat')]
# Out:
#                       car    type  year   price finance  day    dealer  \
# 0   Mercedes-Benz A-Class   sedan  2019   39000      no  Sun      Mike
# 2           Nissan Altima   sedan  2015   17500      no  Sun      Mike
# 7                 Audi A6   sedan  2020   78444      no  Sat  Brittany
# 17                Audi A6   sedan  2015   58444     yes  Sat  Brittany
# 18              Jaguar XF   sedan  2019   57744     yes  Sun    Turner
# 30            Honda Civic   sedan  2000    2333      no  Sat  Brittany
# 32       Maserati Levante     SUV  2020  134325     yes  Sun      Mike
# 34          Ford Maverick  pickup  2013   36033     yes  Sun    Turner
# 41          Jeep Wrangler     SUV  2002    3553      no  Sun  Brittany
# 42           Genesis GV80     SUV  2020   77842     yes  Sat      Mike
#
#    customer  social_security  sex
# 0   Stanley        555342396    M
# 2      Todd        998573477    M
# 7    Shelby        223955366    F
# 17   Qatava        223855366    M
# ...

# %%
df[df['day'].isin(['Mon', 'Tue', 'Wed', 'Thur', 'Fri'])]
# Out:
#                       car       type  year   price finance   day    dealer  \
# 1                 Audi A6      sedan  2021   67800     yes   Mon       Sam
# 3       Chevrolet Equinox        SUV  2013    9600      no   Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000     yes  Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000     yes   Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500      no   Tue    Turner
# 8           Jeep Wrangler        SUV  2017   33553     yes   Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855      no   Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434      no   Mon     Maddy
# 11         Hyundai Accent  hatchback  2011    7434      no   Wed     Maddy
# 12  Mercedes-Benz A-Class  hatchback  2015   25453     yes   Tue      Mike
# 13          Nissan Altima      sedan  2010   10983      no   Mon    Turner
# ...

# %% [markdown]
# ## Pandas Methods

# %%
def price_after_tax(price):
    return round(price * 1.13, 0)

# %%
price_after_tax(df['price'][7])
# Out:
# 88642.0

# %%
df['price_after_tax'] = df["price"].apply(price_after_tax)

# %%
df
# Out:
#                       car       type  year   price finance    day    dealer  \
# 0   Mercedes-Benz A-Class      sedan  2019   39000      no    Sun      Mike
# 1                 Audi A6      sedan  2021   67800     yes    Mon       Sam
# 2           Nissan Altima      sedan  2015   17500      no    Sun      Mike
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000     yes   Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000     yes    Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 7                 Audi A6      sedan  2020   78444      no    Sat  Brittany
# 8           Jeep Wrangler        SUV  2017   33553     yes    Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
def profit_margin(price, finance):
    if finance == "no":
        if price < 10000:
            return "LOW"
        elif price >= 10000 and price < 25000:
            return "MED"
        else:
            return "HIGH"
    else:
        if price < 7500:
            return "LOW"
        elif price >= 7500 and price < 20000:
            return "MED"
        else:
            return "HIGH"

# %%
profit_margin(150000, "no")
# Out:
# 'HIGH'

# %%
df["profit_margin"] = df[['price','finance']].apply(lambda df: profit_margin(df['price'],df['finance']),axis=1)

# %%
df
# Out:
#                       car       type  year   price finance    day    dealer  \
# 0   Mercedes-Benz A-Class      sedan  2019   39000      no    Sun      Mike
# 1                 Audi A6      sedan  2021   67800     yes    Mon       Sam
# 2           Nissan Altima      sedan  2015   17500      no    Sun      Mike
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000     yes   Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000     yes    Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 7                 Audi A6      sedan  2020   78444      no    Sat  Brittany
# 8           Jeep Wrangler        SUV  2017   33553     yes    Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
df['profit_margin'] = np.vectorize(profit_margin)(df['price'], df['finance'])

# %%
df
# Out:
#                       car       type  year   price finance    day    dealer  \
# 0   Mercedes-Benz A-Class      sedan  2019   39000      no    Sun      Mike
# 1                 Audi A6      sedan  2021   67800     yes    Mon       Sam
# 2           Nissan Altima      sedan  2015   17500      no    Sun      Mike
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000     yes   Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000     yes    Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 7                 Audi A6      sedan  2020   78444      no    Sat  Brittany
# 8           Jeep Wrangler        SUV  2017   33553     yes    Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
df.describe()
# Out:
#               year          price  social_security  price_after_tax
# count    45.000000      45.000000     4.500000e+01        45.000000
# mean   2016.222222   54373.377778     6.358065e+08     61441.888889
# std       5.603931   50910.915441     3.096242e+08     57529.393065
# min    2000.000000    2235.000000     7.006635e+07      2526.000000
# 25%    2015.000000   17434.000000     3.346424e+08     19700.000000
# 50%    2018.000000   43553.000000     5.795217e+08     49215.000000
# 75%    2020.000000   78422.000000     9.475778e+08     88617.000000
# max    2022.000000  232000.000000     9.985735e+08    262160.000000

# %%
df.describe().transpose()
# Out:
#                  count          mean           std         min          25%  \
# year              45.0  2.016222e+03  5.603931e+00      2000.0       2015.0
# price             45.0  5.437338e+04  5.091092e+04      2235.0      17434.0
# social_security   45.0  6.358065e+08  3.096242e+08  70066354.0  334642443.0
# price_after_tax   45.0  6.144189e+04  5.752939e+04      2526.0      19700.0
#
#                          50%          75%          max
# year                  2018.0       2020.0       2022.0
# price                43553.0      78422.0     232000.0
# social_security  579521683.0  947577792.0  998573477.0
# price_after_tax      49215.0      88617.0     262160.0

# %%
df.sort_values('price')
# Out:
#                       car       type  year   price finance    day    dealer  \
# 19       Volkswagen Jetta      sedan  2004    2235      no    Tue    Turner
# 30            Honda Civic      sedan  2000    2333      no    Sat  Brittany
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 41          Jeep Wrangler        SUV  2002    3553      no    Sun  Brittany
# 11         Hyundai Accent  hatchback  2011    7434      no    Wed     Maddy
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 13          Nissan Altima      sedan  2010   10983      no    Mon    Turner
# 38         Hyundai Accent  hatchback  2015   13434     yes  Thurs  Brittany
# 37         Hyundai Accent  hatchback  2015   13434     yes  Thurs  Brittany
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
df.sort_values(['price', 'sex'])
# Out:
#                       car       type  year   price finance    day    dealer  \
# 19       Volkswagen Jetta      sedan  2004    2235      no    Tue    Turner
# 30            Honda Civic      sedan  2000    2333      no    Sat  Brittany
# 6        Volkswagen Jetta      sedan  2000    3500      no    Tue    Turner
# 41          Jeep Wrangler        SUV  2002    3553      no    Sun  Brittany
# 11         Hyundai Accent  hatchback  2011    7434      no    Wed     Maddy
# 3       Chevrolet Equinox        SUV  2013    9600      no    Wed    Turner
# 9        Volkswagen Jetta      sedan  2012    9855      no    Tue       Sam
# 13          Nissan Altima      sedan  2010   10983      no    Mon    Turner
# 37         Hyundai Accent  hatchback  2015   13434     yes  Thurs  Brittany
# 38         Hyundai Accent  hatchback  2015   13434     yes  Thurs  Brittany
# 10         Hyundai Accent  hatchback  2014   17434      no    Mon     Maddy
# ...

# %%
df['price'].max()
# Out:
# 232000

# %%
df['price'].idxmax()
# Out:
# 44

# %%
df.iloc[44]
# Out:
# car                Bentley Bentayga
# type                            SUV
# year                           2020
# price                        232000
# finance                          no
# day                             Wed
# dealer                         Mike
# customer                  Gabrielle
# social_security           885353455
# sex                               F
# price_after_tax            262160.0
# profit_margin                  HIGH
# Name: 44, dtype: object

# %%
df['sex'].value_counts()
# Out:
# M    26
# F    19
# Name: sex, dtype: int64

# %%
df["finance"] = df["finance"].replace(to_replace='no',value='N')

# %%
df["finance"] = df["finance"].replace(to_replace='yes',value='Y')

# %%
df
# Out:
#                       car       type  year   price finance    day    dealer  \
# 0   Mercedes-Benz A-Class      sedan  2019   39000       N    Sun      Mike
# 1                 Audi A6      sedan  2021   67800       Y    Mon       Sam
# 2           Nissan Altima      sedan  2015   17500       N    Sun      Mike
# 3       Chevrolet Equinox        SUV  2013    9600       N    Wed    Turner
# 4          Hyundai Accent  hatchback  2017   23000       Y   Thur     Maddy
# 5         Porsche Cayenne      coupe  2021   82000       Y    Fri      Mike
# 6        Volkswagen Jetta      sedan  2000    3500       N    Tue    Turner
# 7                 Audi A6      sedan  2020   78444       N    Sat  Brittany
# 8           Jeep Wrangler        SUV  2017   33553       Y    Fri      Mike
# 9        Volkswagen Jetta      sedan  2012    9855       N    Tue       Sam
# 10         Hyundai Accent  hatchback  2014   17434       N    Mon     Maddy
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35     True
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#                car       type  year  price finance    day    dealer customer  \
# 35   Jeep Wrangler        SUV  2021  43553       Y    Fri      Mike      Don
# 38  Hyundai Accent  hatchback  2015  13434       Y  Thurs  Brittany      Don
#
#     social_security sex
# 35        277425852   M
# 38        277425852   M

# %%
df['customer'].unique()
# Out:
# array(['Stanley', 'Brittany', 'Todd', 'Jasime', 'Sam', 'Morgan', 'Aaron',
#        'Shelby', 'Jessie', 'Taylor', 'Monte', 'Alyssa', 'Felix', 'Kyle',
#        'Nicole', 'Jan', 'Qatava', 'Git', 'Jon', 'Sal', 'Murry', 'Don',
#        'Selena', 'Emily', 'Pam', 'Cam', 'Bob', 'Allen', 'Sarah', 'Bailey',
#        'Harris', 'Rachel', 'Porsche', 'Edward', 'Gabrielle'], dtype=object)

# %%
df['customer'].nunique()
# Out:
# 35

# %%
df['price'].between(10000,20000)
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29     True
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: price, dtype: bool

# %%
df[df['price'].between(10000,20000)]
# Out:
#                car       type  year  price finance    day    dealer customer  \
# 2    Nissan Altima      sedan  2015  17500       N    Sun      Mike     Todd
# 10  Hyundai Accent  hatchback  2014  17434       N    Mon     Maddy   Taylor
# 13   Nissan Altima      sedan  2010  10983       N    Mon    Turner    Felix
# 29  Hyundai Accent  hatchback  2017  17434       N  Thurs     Maddy      Bob
# 37  Hyundai Accent  hatchback  2015  13434       Y  Thurs  Brittany      Don
# 38  Hyundai Accent  hatchback  2015  13434       Y  Thurs  Brittany      Don
#
#     social_security sex
# 2         998573477   M
# 10        870566354   F
# 13        994853335   M
# 29         70066354   M
# 37        277425852   M
# 38        277425852   M

# %% [markdown]
# ### Groupby
